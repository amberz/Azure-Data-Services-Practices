# %%
# create Azure Databricks with 6.6 runtime (includes Apache Spark 2.4.5, Scala 2.11), create a Python notebook to run below query
# azureml-core of version 1.0.72 or higher is required
from azureml.core import Workspace, Dataset

#get dataset
subscription_id = '**********'
resource_group = 'AIMLRG'
workspace_name = 'AMLEnterprise816'

workspace = Workspace(subscription_id, resource_group, workspace_name)

#create a dataset from AML via upload Iris csv file with tabular format. 
dataset = Dataset.get_by_name(workspace, name='IrisData2')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Performing interactive authentication. Please follow the instructions on the terminal.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code FMDZA4BYZ to authenticate.
# You have logged in. Now let us find all the subscriptions to which you have access...
# Interactive authentication successfully completed.
# </div>

# %%
#get the dataset with spark dataframe
df=dataset.to_spark_dataframe()
print(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame[plant_number: string, sepal_length: double, sepal_width: double, petal_length: double, petal_width: double, species: string]
# </div>
